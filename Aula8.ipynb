# %%
import pandas as pd
import math



# a) Ler o arquivo Excel e colocar em um dataframe

CAMINHO = "C:\\Users\\FIC\\Documents\\Eder do Nascimento Bernardo\\arquivos\\003 - Arquivos\\"
ARQUIVO = "vendas.xlsx"

# %%
# b) coloque em um dataframe.

df = pd.read_excel(CAMINHO + ARQUIVO, sheet_name= 'Planilha1')

# %%
## c) Visualize o cabeçalho dos dados;

df.head()
# Out:
#     Coluna 1           Coluna 2                 Coluna 3 Coluna 4 Coluna 5  \
# 0 2014-01-01  Bernardo de Sousa  Supervisor de Vendas Pl     ACME       AL
# 1 2014-01-01  Bernardo de Sousa  Supervisor de Vendas Pl     ACME       AP
# 2 2014-01-01  Bernardo de Sousa  Supervisor de Vendas Pl     ACME       MA
# 3 2014-01-01  Bernardo de Sousa  Supervisor de Vendas Pl     ACME       MG
# 4 2014-01-01  Bernardo de Sousa  Supervisor de Vendas Pl     ACME       MS
#
#    Coluna 6
# 0   3276.20
# 1   3005.86
# 2   8568.54
# 3   1344.27
# 4   7585.04

# %%
# c) Visualize as últimas linhas;

df.tail()
# Out:
#          Coluna 1            Coluna 2      Coluna 3        Coluna 4 Coluna 5  \
# 130461 2016-12-31  Liz Azevedo Santos  Vendedor Pl.  Planet Express       PI
# 130462 2016-12-31  Liz Azevedo Santos  Vendedor Pl.  Planet Express       PR
# 130463 2016-12-31  Liz Azevedo Santos  Vendedor Pl.  Planet Express       RO
# 130464 2016-12-31  Liz Azevedo Santos  Vendedor Pl.  Planet Express       RR
# 130465 2016-12-31  Liz Azevedo Santos  Vendedor Pl.  Planet Express       SC
#
#         Coluna 6
# 130461   1829.39
# 130462   2378.48
# 130463   4488.47
# 130464   1543.66
# 130465   9820.71

# %%
# d) Renomear o cabeçalho da tabela
df.columns = ['Data','Vendedor','Cargo','Cliente','UF','Vendas']

# %%
df.head()
# Out:
#         Data           Vendedor                    Cargo Cliente  UF   Vendas
# 0 2014-01-01  Bernardo de Sousa  Supervisor de Vendas Pl    ACME  AL  3276.20
# 1 2014-01-01  Bernardo de Sousa  Supervisor de Vendas Pl    ACME  AP  3005.86
# 2 2014-01-01  Bernardo de Sousa  Supervisor de Vendas Pl    ACME  MA  8568.54
# 3 2014-01-01  Bernardo de Sousa  Supervisor de Vendas Pl    ACME  MG  1344.27
# 4 2014-01-01  Bernardo de Sousa  Supervisor de Vendas Pl    ACME  MS  7585.04

# %%
# e) Quais são os tipos de dados no dataframe?
df.info
# Out:
# <bound method DataFrame.info of              Data            Vendedor                    Cargo  \
# 0      2014-01-01   Bernardo de Sousa  Supervisor de Vendas Pl
# 1      2014-01-01   Bernardo de Sousa  Supervisor de Vendas Pl
# 2      2014-01-01   Bernardo de Sousa  Supervisor de Vendas Pl
# 3      2014-01-01   Bernardo de Sousa  Supervisor de Vendas Pl
# 4      2014-01-01   Bernardo de Sousa  Supervisor de Vendas Pl
# ...           ...                 ...                      ...
# 130461 2016-12-31  Liz Azevedo Santos             Vendedor Pl.
# 130462 2016-12-31  Liz Azevedo Santos             Vendedor Pl.
# 130463 2016-12-31  Liz Azevedo Santos             Vendedor Pl.
# 130464 2016-12-31  Liz Azevedo Santos             Vendedor Pl.
# 130465 2016-12-31  Liz Azevedo Santos             Vendedor Pl.
#
#                Cliente  UF   Vendas
# 0                 ACME  AL  3276.20
# 1                 ACME  AP  3005.86
# 2                 ACME  MA  8568.54
# ...

# %%
# f) Há valores faltantes ou nulos?
print(df.isnull().sum())
# Out:
# Data        0
# Vendedor    0
# Cargo       0
# Cliente     0
# UF          0
# Vendas      0
# dtype: int64

# %%
### i) Calcule a soma, média, máximo, mínimo e contagem da coluna Preço.

print('O maior valor é',df['Vendas'].sum())

print('A media dos valores é',df['Vendas'].mean())

print('O maior valor é',df['Vendas'].max())

print('O menor valor é',df['Vendas'].min()) 

print('Nesta Coluna existe',df['Vendas'].count())
# Out:
# O maior valor é 718501609.25
# A media dos valores é 5507.194282418408
# O maior valor é 10000.0
# O menor valor é 1000.01
# Nesta Coluna existe 130466

# %%
# j) Crie um programa para criar um dataframe para mostrar
## as vendas por cargo, e salvar um arquivo em csv para com
## o nome de cada cargo:
#▪ Supervisor de Vendas Pl
#▪ Gerente Regional Jr.
#▪ Supervisor de Vendas Sr
#▪ Coordenador de Vendas Pl.
#▪ Vendedor Jr.
#▪ Vendedor Sr.
#▪ Vendedor Pl.
#▪ Gerente Regional Pl.
#▪ Coordenador de Vendas Sr.
#▪ Coordenador de Vendas Jr.
#▪ Supervisor de Vendas Jr.

##  Filtrar um dataframe Supervisor de Vendas Pl

df_supervisorp1 = df[df['Cargo']=='Supervisor de Vendas Pl']


## diretorio de destino para salvar o arquico
pasta_destino = 'C:\\Users\\FIC\\Documents\\Eder do Nascimento Bernardo\\Supervisor'

## nome do arquivo
nome_arquivo = 'supervisorp1.csv'

## salvar \ gerar um arquivo em excel

df_supervisorp1.to_csv(pasta_destino + nome_arquivo)

# %%
#▪ Gerente Regional Jr.
#▪ Supervisor de Vendas Sr
#▪ Coordenador de Vendas Pl.
#▪ Vendedor Jr.
#▪ Vendedor Sr.
#▪ Vendedor Pl.
#▪ Gerente Regional Pl.
#▪ Coordenador de Vendas Sr.
#▪ Coordenador de Vendas Jr.
#▪ Supervisor de Vendas Jr.

##  Filtrar um dataframe Supervisor de Vendas Pl

df_Gerente_Regional_Jr = df[df['Cargo']=='Gerente_Regional_Jr']


## diretorio de destino para salvar o Arquivo
pasta_destino = 'C:\\Users\\FIC\\Documents\\Eder do Nascimento Bernardo\\Gerente_Regional_Jr'
## nome do arquivo
nome_arquivo = 'Gerente_Regional_Jr.csv'

## salvar \ gerar um arquivo em excel

df_Gerente_Regional_Jr.to_csv(pasta_destino + nome_arquivo)

# %%
# Supervisor_de_Vendas_Sr
# Coordenador_de_Vendas_Pl.
# Vendedor_Jr.
# Vendedor_Sr.
# Vendedor_Pl.
# Gerente_Regional Pl.
# Coordenador_de_Vendas_Sr.
# Coordenador_de_Vendas_Jr.
# Supervisor_de_Vendas Jr.

##  Filtrar um dataframe Supervisor de Vendas Pl

df_Gerente_Regional_Jr = df[df['Cargo']=='Gerente_Regional_Jr']


## diretorio de destino para salvar o Arquivo
pasta_destino = 'C:\\Users\\FIC\\Documents\\Eder do Nascimento Bernardo\\Gerente_Regional_Jr'
## nome do arquivo
nome_arquivo = 'Gerente_Regional_Jr.csv'

## salvar \ gerar um arquivo em excel

df_Gerente_Regional_Jr.to_csv(pasta_destino + nome_arquivo, encoding='ANSI')

# %%
# k) Dataframes para cada coluna com dados únicos
### criar um data frame apenas com a coluna cargo ###
dados_cargo = df['cargo']

## contar quantos elementos exitem antes de remover as duplicadas


#### removendo as duplicadas do datafra e sem duplicadas ####
dados_cargo = dados_cargo.drop_duplicates
### quantos elementos ficaram apos a remoção das duplicadas 

dados_cargo.count()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Python311\Lib\site-packages\pandas\core\indexes\base.py:3790, in Index.get_loc(self, key)
#    3789 try:
# -> 3790     return self._engine.get_loc(casted_key)
#    3791 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'cargo'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# c:\Users\FIC\Documents\Eder do Nascimento Bernardo\Aula8.ipynb Cell 13 line 3
# ...

# %%
# j) Criar e salvar dataframes para cada cargo
cargos = df['Cargo'].unique()
for cargo in cargos:
    cargo_df = df[df['Cargo'] == cargo]
    cargo_df.to_csv(f'{cargo}.csv', index=False)

# %%
# k) Dataframes para cada coluna com dados únicos
dataframes_colunas_unicas = {}
for coluna in df.columns:
    dataframes_colunas_unicas[coluna] = df[coluna].unique()

# %%
for coluna, valores in dataframes_colunas_unicas.items():
    print(f"\nValores únicos na coluna '{coluna}':")
    for valor in valores:
        print(valor)
# Out:
# Valores únicos na coluna 'Data':
# 2014-01-01 00:00:00
# 2014-01-02 00:00:00
# 2014-01-03 00:00:00
# 2014-01-04 00:00:00
# 2014-01-05 00:00:00
# 2014-01-06 00:00:00
# 2014-01-07 00:00:00
# 2014-01-08 00:00:00
# 2014-01-09 00:00:00
# 2014-01-10 00:00:00
# 2014-01-11 00:00:00
# 2014-01-12 00:00:00
# 2014-01-13 00:00:00
# 2014-01-14 00:00:00
# 2014-01-15 00:00:00
# 2014-01-16 00:00:00
# 2014-01-17 00:00:00
# 2014-01-18 00:00:00
# 2014-01-19 00:00:00
# 2014-01-20 00:00:00
# 2014-01-21 00:00:00
# 2014-01-22 00:00:00
# 2014-01-23 00:00:00
# 2014-01-24 00:00:00
# 2014-01-25 00:00:00
# 2014-01-26 00:00:00
# 2014-01-27 00:00:00
# 2014-01-28 00:00:00
# 2014-01-29 00:00:00
# 2014-01-30 00:00:00
# 2014-01-31 00:00:00
# 2014-02-01 00:00:00
# 2014-02-02 00:00:00
# 2014-02-03 00:00:00
# 2014-02-04 00:00:00
# 2014-02-05 00:00:00
# 2014-02-06 00:00:00
# 2014-02-07 00:00:00
# 2014-02-08 00:00:00
# 2014-02-09 00:00:00
# 2014-02-10 00:00:00
# 2014-02-11 00:00:00
# 2014-02-12 00:00:00
# ...
